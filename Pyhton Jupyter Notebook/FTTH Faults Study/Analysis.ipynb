# %%
# USING PACKAGES
import pandas as pd

# %%
# DATA TYEPS HANDLING OF CLEAR VIEW DATA
cv = pd.read_csv("/home/Programming Projects/Python_Mojo/Jupyter Notebook/FTTH Faults Study/Clear View FTTH.csv")
cv["TEL_NO"] = cv["TEL_NO"].astype("string")
cv["DATE_OF_COLLECTION"] = pd.to_datetime(cv["DATE_OF_COLLECTION"])
# cv.insert(5, "NUMBER_OF_CUSTOMERS", True)
# cv["NUMBER_OF_CUSTOMERS"] = cv["PORT"].apply(lambda i : i.split("#")[1] )
# cv["PORT"] = cv["PORT"].apply(lambda i : i.split("#")[0] )
cv["NUMBER_OF_CUSTOMERS"] = cv["NUMBER_OF_CUSTOMERS"].astype("int")
cv.head()
# Out:
#   DATE_OF_COLLECTION Exchange_Name    TEL_NO               DSLAM     PORT  \
# 0         2024-01-14     تل المنيا  38442446  TALMINY-G01H-GZ-EG    0-5-1
# 1         2024-01-31       ح.حلوان  23258445  HDYKHLWN-G01H-C-EG   0-16-4
# 2         2024-01-31       ح.حلوان  23777559  HDYKHLWN-G01H-C-EG  0-17-12
# 3         2024-01-31       ح.حلوان  23259286  HDYKHLWN-G01H-C-EG  0-16-15
# 4         2024-01-31       ح.حلوان  23769397  HDYKHLWN-G01H-C-EG   0-16-1
#
#    NUMBER_OF_CUSTOMERS SERVICE_PRODUCT  DS_ATTENUATION  TX_POWER_DS  \
# 0                    9        30M_FTTH           23.92         7.19
# 1                    2        30M_FTTH           22.60         3.71
# 2                    4        30M_FTTH           21.42         3.68
# 3                    2        30M_FTTH           26.99         3.53
# 4                    4        30M_FTTH           21.54         3.77
#
#    RX_POWER_DS   RANGE  LINE_STATE LINK_QUALITY_SHORT_TERM  \
# ...

# %%
# DATA TYEPS HANDLING OF CLOSED COMPLAINS DATA
cc = pd.read_csv("/home/Programming Projects/Python_Mojo/Jupyter Notebook/FTTH Faults Study/Closed Compalins FTTH.csv")
cc["Compalin_Time"] = pd.to_datetime(cc["Compalin_Time"])
cc["Close_Time"] = pd.to_datetime(cc["Close_Time"])
cc["TEL_NO"] = cc["TEL_NO"].astype("string")
cc["Close_Code"] = cc["Close_Code"].astype("string")
cc.head()
# Out:
#   Exchange_Name        Complain_Type_Name    TEL_NO Close_Code  \
# 0       15 مايو  FTTH-Wrong card and port  25500405         49
# 1       15 مايو  FTTH-Wrong card and port  25500502         49
# 2       15 مايو  FTTH-Data and Voice down  25500598         92
# 3       15 مايو  FTTH-Wrong card and port  25500652         49
# 4       15 مايو  FTTH-Wrong card and port  25500682         79
#
#         Compalin_Time          Close_Time  Duration
# 0 2023-12-30 16:10:00 2024-01-19 17:59:00        20
# 1 2023-12-30 12:38:00 2024-01-19 18:03:00        20
# 2 2024-01-11 19:06:00 2024-01-23 10:27:00        12
# 3 2024-01-19 19:05:00 2024-01-28 10:02:00         9
# 4 2023-11-09 15:07:00 2024-01-02 11:27:00        54
